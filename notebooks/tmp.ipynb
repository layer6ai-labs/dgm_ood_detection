# %%
import pandas as pd

df = pd.read_csv('tables/tmp.csv')
df
# Out:
#     LID  _defaultColorIndex        id  log-likelihood  \
# 0     0                   3  pj8bx3by    61677.277344
# 1   187                   3  pj8bx3by    47177.789062
# 2     0                   3  pj8bx3by    68629.656250
# 3     0                   3  pj8bx3by    60570.726562
# 4   147                   3  pj8bx3by    49196.398438
# 5     0                   3  pj8bx3by    55857.312500
# 6    65                   3  pj8bx3by    52358.644531
# 7    51                   3  pj8bx3by    54395.527344
# 8     0                   3  pj8bx3by    65075.601562
# 9     0                   3  pj8bx3by    62322.894531
# 10   72                   3  pj8bx3by    52387.898438
# 11    1                   3  pj8bx3by    59854.269531
# 12    0                   3  pj8bx3by    66850.343750
# 13    0                   3  pj8bx3by    58125.027344
# 14   71                   3  pj8bx3by    52128.265625
# 15    0                   3  pj8bx3by    65117.886719
# ...

# %%
# get the average of the values in the column LID

df['LID'].mean()
# Out:
# 31.925
